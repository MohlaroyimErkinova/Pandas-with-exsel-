# %%
import pandas as pd
{
    "FISH":[ "Qadamova Zulayho", "Xalilov Durbek", "Djalilov M", "Jorayeva G", "Arabboyev A", " Turdimatov M", "Abdullayeva M", "Abduvaliyev I",   ],
    "Fan nomi" :[ "Sun'iy intellekt ", "Sun'i yey intellekt", "Kompyuterni tashkil etish", "Elektronika va sxemalar", "Kiberxavfsizlik asoslari", "Kiberxavfsizlik asoslari", "Ma'lumotlar tuzilmasi va algoritmlar", "Kompyuterni tashkil etish", ],
    "Mashg'ulot turi":["amaliy", "ma'ruza ", "ma'ruza", "ma'ruza ", "amaliy ", "ma'ruza", "amaliy", " amali "],
    "kafedrasi":["Axborot texnologiyalari", "Axborot texnologiyalari", "Kompyuter tizimlar ", "Tabiy fanlar ", "Axborot texnologiyalar", "Axborot texnologiyalar", "Axborot texnologiyalar", "Axborot texnologiyalar"  ]






}
db=pd.DataFrame(baza)
print(db)
# Out:
#                FISH                              Fan nomi Mashg'ulot turi  \
# 0  Qadamova Zulayho                     Sun'iy intellekt           amaliy
# 1    Xalilov Durbek                   Sun'i yey intellekt        ma'ruza
# 2       Djalilov sM             Kompyuterni tashkil etish         ma'ruza
# 3        Jorayeva G               Elektronika va sxemalar        ma'ruza
# 4       Arabboyev A              Kiberxavfsizlik asoslari         amaliy
# 5      Turdimatov M              Kiberxavfsizlik asoslari         ma'ruza
# 6     Abdullayeva M  Ma'lumotlar tuzilmasi va algoritmlar          amaliy
# 7     Abduvaliyev I             Kompyuterni tashkil etish          amali
#
#                  kafedrasi
# 0  Axborot texnologiyalari
# 1  Axborot texnologiyalari
# 2      Kompyuter tizimlar
# 3            Tabiy fanlar
# 4   Axborot texnologiyalar
# 5   Axborot texnologiyalar
# 6   Axborot texnologiyalar
# 7   Axborot texnologiyalar

# %%
db.to_excel("teacher.xlsx")
